# %% [markdown]
# # Exercise 2: Airlines problem

# %% [markdown]
# # Hierarchiel Clustering

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.cluster import AgglomerativeClustering
import seaborn as sns

# %%
DF=pd.read_excel('D:/Megha/Desktop/DS assignments/Assignment 7 Clustering/EastWestAirlinesdata.xlsx')
DF
# Out:
#        ID#  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0        1    28143           0          1          1          1          174
# 1        2    19244           0          1          1          1          215
# 2        3    41354           0          1          1          1         4123
# 3        4    14776           0          1          1          1          500
# 4        5    97752           0          4          1          1        43300
# ...    ...      ...         ...        ...        ...        ...          ...
# 3994  4017    18476           0          1          1          1         8525
# 3995  4018    64385           0          1          1          1          981
# 3996  4019    73597           0          3          1          1        25447
# 3997  4020    54899           0          1          1          1          500
# 3998  4021     3016           0          1          1          1            0
#
# ...

# %%
DF.dtypes
# Out:
# ID#                  int64
# Balance              int64
# Qual_miles           int64
# cc1_miles            int64
# cc2_miles            int64
# cc3_miles            int64
# Bonus_miles          int64
# Bonus_trans          int64
# Flight_miles_12mo    int64
# Flight_trans_12      int64
# Days_since_enroll    int64
# Award?               int64
# dtype: object

# %%
import scipy.cluster.hierarchy as sch

# %%
#standardise data
from sklearn.preprocessing import StandardScaler
scaled=StandardScaler()

# %%
df_h=DF

# %%
df_hs=scaled.fit_transform(df_h)
df_hs
# Out:
# array([[-1.73512503e+00, -4.51140783e-01, -1.86298687e-01, ...,
#         -3.62167870e-01,  1.39545434e+00, -7.66919299e-01],
#        [-1.73426342e+00, -5.39456874e-01, -1.86298687e-01, ...,
#         -3.62167870e-01,  1.37995704e+00, -7.66919299e-01],
#        [-1.73340181e+00, -3.20031232e-01, -1.86298687e-01, ...,
#         -3.62167870e-01,  1.41192021e+00, -7.66919299e-01],
#        ...,
#        [ 1.72682006e+00, -4.29480975e-05, -1.86298687e-01, ...,
#         -3.62167870e-01, -1.31560393e+00,  1.30391816e+00],
#        [ 1.72768167e+00, -1.85606976e-01, -1.86298687e-01, ...,
#         -9.85033311e-02, -1.31608822e+00, -7.66919299e-01],
#        [ 1.72854328e+00, -7.00507951e-01, -1.86298687e-01, ...,
#         -3.62167870e-01, -1.31754109e+00, -7.66919299e-01]])

# %%
df_h.columns
# Out:
# Index(['ID#', 'Balance', 'Qual_miles', 'cc1_miles', 'cc2_miles', 'cc3_miles',
#        'Bonus_miles', 'Bonus_trans', 'Flight_miles_12mo', 'Flight_trans_12',
#        'Days_since_enroll', 'Award?'],
#       dtype='object')

# %%
df_hs=pd.DataFrame(df_hs,columns=df_h.columns)
df_hs
# Out:
#            ID#   Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  \
# 0    -1.735125 -0.451141   -0.186299  -0.769578  -0.098242  -0.062767
# 1    -1.734263 -0.539457   -0.186299  -0.769578  -0.098242  -0.062767
# 2    -1.733402 -0.320031   -0.186299  -0.769578  -0.098242  -0.062767
# 3    -1.732540 -0.583799   -0.186299  -0.769578  -0.098242  -0.062767
# 4    -1.731679  0.239678   -0.186299   1.409471  -0.098242  -0.062767
# ...        ...       ...         ...        ...        ...        ...
# 3994  1.725097 -0.547079   -0.186299  -0.769578  -0.098242  -0.062767
# 3995  1.725958 -0.091465   -0.186299  -0.769578  -0.098242  -0.062767
# 3996  1.726820 -0.000043   -0.186299   0.683121  -0.098242  -0.062767
# 3997  1.727682 -0.185607   -0.186299  -0.769578  -0.098242  -0.062767
# 3998  1.728543 -0.700508   -0.186299  -0.769578  -0.098242  -0.062767
#
#       Bonus_miles  Bonus_trans  Flight_miles_12mo  Flight_trans_12  \
# ...

# %%
#plot dendrogram
dendrogram=sch.dendrogram(sch.linkage(df_hs,method='complete'))

# %%
hc=AgglomerativeClustering(n_clusters=5,affinity='euclidean',linkage='complete')
hc
# Out:
# AgglomerativeClustering(linkage='complete', n_clusters=5)

# %%
y=hc.fit_predict(df_hs)
Clusters=pd.DataFrame(y,columns=['Clusters'])

# %%
Clusters.value_counts()
# Out:
# Clusters
# 1           3916
# 4             43
# 2             15
# 0             13
# 3             12
# dtype: int64

# %%
df_h['Hierarchiel Clusters']=y
df_h
# Out:
#        ID#  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0        1    28143           0          1          1          1          174
# 1        2    19244           0          1          1          1          215
# 2        3    41354           0          1          1          1         4123
# 3        4    14776           0          1          1          1          500
# 4        5    97752           0          4          1          1        43300
# ...    ...      ...         ...        ...        ...        ...          ...
# 3994  4017    18476           0          1          1          1         8525
# 3995  4018    64385           0          1          1          1          981
# 3996  4019    73597           0          3          1          1        25447
# 3997  4020    54899           0          1          1          1          500
# 3998  4021     3016           0          1          1          1            0
#
# ...

# %% [markdown]
# # KMeans Clustering

# %%
df_k=DF
df_k
# Out:
#        ID#  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0        1    28143           0          1          1          1          174
# 1        2    19244           0          1          1          1          215
# 2        3    41354           0          1          1          1         4123
# 3        4    14776           0          1          1          1          500
# 4        5    97752           0          4          1          1        43300
# ...    ...      ...         ...        ...        ...        ...          ...
# 3994  4017    18476           0          1          1          1         8525
# 3995  4018    64385           0          1          1          1          981
# 3996  4019    73597           0          3          1          1        25447
# 3997  4020    54899           0          1          1          1          500
# 3998  4021     3016           0          1          1          1            0
#
# ...

# %%
df_k.drop(['Hierarchiel Clusters'],axis=1,inplace=True)
df_k
# Out:
#        ID#  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0        1    28143           0          1          1          1          174
# 1        2    19244           0          1          1          1          215
# 2        3    41354           0          1          1          1         4123
# 3        4    14776           0          1          1          1          500
# 4        5    97752           0          4          1          1        43300
# ...    ...      ...         ...        ...        ...        ...          ...
# 3994  4017    18476           0          1          1          1         8525
# 3995  4018    64385           0          1          1          1          981
# 3996  4019    73597           0          3          1          1        25447
# 3997  4020    54899           0          1          1          1          500
# 3998  4021     3016           0          1          1          1            0
#
# ...

# %%
df=df_k

# %%
df_k=scaled.fit_transform(df_k)
df_k
# Out:
# array([[-1.73512503e+00, -4.51140783e-01, -1.86298687e-01, ...,
#         -3.62167870e-01,  1.39545434e+00, -7.66919299e-01],
#        [-1.73426342e+00, -5.39456874e-01, -1.86298687e-01, ...,
#         -3.62167870e-01,  1.37995704e+00, -7.66919299e-01],
#        [-1.73340181e+00, -3.20031232e-01, -1.86298687e-01, ...,
#         -3.62167870e-01,  1.41192021e+00, -7.66919299e-01],
#        ...,
#        [ 1.72682006e+00, -4.29480975e-05, -1.86298687e-01, ...,
#         -3.62167870e-01, -1.31560393e+00,  1.30391816e+00],
#        [ 1.72768167e+00, -1.85606976e-01, -1.86298687e-01, ...,
#         -9.85033311e-02, -1.31608822e+00, -7.66919299e-01],
#        [ 1.72854328e+00, -7.00507951e-01, -1.86298687e-01, ...,
#         -3.62167870e-01, -1.31754109e+00, -7.66919299e-01]])

# %%
from sklearn.cluster import KMeans
wcss=[]
for i in range (1,11):
    kmeans=KMeans(n_clusters=i,random_state=12)
    kmeans.fit(df_k)
    wcss.append(kmeans.inertia_)
plt.plot(range(1,11),wcss)
plt.show()

# %%
#run program for seeds 2,7

# %%
clusters_2=KMeans(2,random_state=6)
clusters_2.fit(df_k)
# Out:
# KMeans(n_clusters=2, random_state=6)

# %%
clusters_2.labels_
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
df['clusters']=clusters_2.labels_

# %%
df
# Out:
#        ID#  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0        1    28143           0          1          1          1          174
# 1        2    19244           0          1          1          1          215
# 2        3    41354           0          1          1          1         4123
# 3        4    14776           0          1          1          1          500
# 4        5    97752           0          4          1          1        43300
# ...    ...      ...         ...        ...        ...        ...          ...
# 3994  4017    18476           0          1          1          1         8525
# 3995  4018    64385           0          1          1          1          981
# 3996  4019    73597           0          3          1          1        25447
# 3997  4020    54899           0          1          1          1          500
# 3998  4021     3016           0          1          1          1            0
#
# ...

# %%
clusters_2.cluster_centers_
# Out:
# array([[ 0.25941178, -0.2971323 , -0.07776117, -0.53018222,  0.01592006,
#         -0.05509239, -0.47817952, -0.43441977, -0.18124569, -0.1980441 ,
#         -0.26320474, -0.33413754],
#        [-0.52116588,  0.59694752,  0.15622447,  1.06515164, -0.03198386,
#          0.11068223,  0.96067668,  0.87276206,  0.36412791,  0.39787641,
#          0.52878604,  0.67129212]])

# %%
df.groupby('clusters').agg(['mean']).reset_index()
# Out:
#   clusters          ID#        Balance  Qual_miles cc1_miles cc2_miles  \
#                    mean           mean        mean      mean      mean
# 0        0  2315.736428   43663.326095   83.929614  1.329465  1.016848
# 1        1  1409.586596  133815.485693  265.164157  3.527861  1.009789
#
#   cc3_miles   Bonus_miles Bonus_trans Flight_miles_12mo Flight_trans_12  \
#        mean          mean        mean              mean            mean
# 0  1.001498   5597.224261    7.432048        207.500187        0.625983
# 1  1.033886  40370.522590   19.988705        968.019578        2.877259
#
#   Days_since_enroll    Award?
#                mean      mean
# 0       3575.285286  0.209285
# 1       5211.243976  0.694277

# %%
df.clusters.value_counts()
# Out:
# 0    2671
# 1    1328
# Name: clusters, dtype: int64

# %%
#with 7 seeds

# %%
df.drop(['clusters'],axis=1,inplace=True)
clusters_4=KMeans(7,random_state=12)
clusters_4.fit(df_k)
# Out:
# KMeans(n_clusters=7, random_state=12)

# %%
df['clusters_4']=clusters_4.labels_
df
# Out:
#        ID#  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0        1    28143           0          1          1          1          174
# 1        2    19244           0          1          1          1          215
# 2        3    41354           0          1          1          1         4123
# 3        4    14776           0          1          1          1          500
# 4        5    97752           0          4          1          1        43300
# ...    ...      ...         ...        ...        ...        ...          ...
# 3994  4017    18476           0          1          1          1         8525
# 3995  4018    64385           0          1          1          1          981
# 3996  4019    73597           0          3          1          1        25447
# 3997  4020    54899           0          1          1          1          500
# 3998  4021     3016           0          1          1          1            0
#
# ...

# %%
clusters_3.cluster_centers_
# Out:
# array([[1.54990798e+03, 1.80185326e+05, 2.83573748e+02, 3.02841678e+00,
#         1.00947226e+00, 1.02976996e+00, 3.51542030e+04, 1.74384303e+01,
#         9.64081191e+02, 2.80514208e+00, 4.97667794e+03, 4.97970230e-01],
#        [2.14312223e+03, 3.84948421e+04, 1.05336355e+02, 1.81275399e+00,
#         1.01562988e+00, 1.00750234e+00, 1.23286049e+04, 1.00869022e+01,
#         3.21210066e+02, 9.60925289e-01, 3.87967865e+03, 3.32916536e-01],
#        [9.18573770e+02, 6.23438574e+05, 4.88229508e+02, 3.26229508e+00,
#         1.01639344e+00, 1.04918033e+00, 5.15422459e+04, 2.03442623e+01,
#         1.63534426e+03, 5.67213115e+00, 6.25019672e+03, 7.86885246e-01]])

# %%
df.groupby(['clusters_4']).agg(['mean']).reset_index()
# Out:
#   clusters_4          ID#        Balance   Qual_miles cc1_miles cc2_miles  \
#                      mean           mean         mean      mean      mean
# 0          0  1091.829905   56930.871044    56.289557  1.356013  1.000000
# 1          1  2269.372093   68876.581395    23.255814  1.139535  2.348837
# 2          2  2083.603448  118527.293103  5486.241379  2.051724  1.000000
# 3          3  1664.866667  138061.400000    78.800000  3.466667  1.000000
# 4          4  3136.521155   39684.451981    39.757555  1.373405  1.000000
# 5          5  1548.853877  125476.972167    58.794235  3.935388  1.000000
# 6          6  1656.112903  202773.451613   535.758065  2.403226  1.000000
#
#   cc3_miles   Bonus_miles Bonus_trans Flight_miles_12mo Flight_trans_12  \
#        mean          mean        mean              mean            mean
# 0  1.000791   5732.325949    7.838608        238.314873        0.722310
# 1  1.000000  14689.837209   17.534884        582.627907        2.209302
# ...

# %%
#optimal clusters =2

# %%
df['clusters_4'].value_counts()
# Out:
# 4    1489
# 0    1264
# 5    1006
# 6     124
# 2      58
# 1      43
# 3      15
# Name: clusters_4, dtype: int64

# %% [markdown]
# # DBSCAN

# %%
df_db=DF
df_db
# Out:
#        ID#  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0        1    28143           0          1          1          1          174
# 1        2    19244           0          1          1          1          215
# 2        3    41354           0          1          1          1         4123
# 3        4    14776           0          1          1          1          500
# 4        5    97752           0          4          1          1        43300
# ...    ...      ...         ...        ...        ...        ...          ...
# 3994  4017    18476           0          1          1          1         8525
# 3995  4018    64385           0          1          1          1          981
# 3996  4019    73597           0          3          1          1        25447
# 3997  4020    54899           0          1          1          1          500
# 3998  4021     3016           0          1          1          1            0
#
# ...

# %%
df_db.drop(['cluster'],axis=1,inplace=True)
df_db
# Out:
#        ID#  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0        1    28143           0          1          1          1          174
# 1        2    19244           0          1          1          1          215
# 2        3    41354           0          1          1          1         4123
# 3        4    14776           0          1          1          1          500
# 4        5    97752           0          4          1          1        43300
# ...    ...      ...         ...        ...        ...        ...          ...
# 3994  4017    18476           0          1          1          1         8525
# 3995  4018    64385           0          1          1          1          981
# 3996  4019    73597           0          3          1          1        25447
# 3997  4020    54899           0          1          1          1          500
# 3998  4021     3016           0          1          1          1            0
#
# ...

# %%
array=df_db.values

# %%
dbs=scaled.fit_transform(array)
dbs
# Out:
# array([[-1.73512503e+00, -4.51140783e-01, -1.86298687e-01, ...,
#         -3.62167870e-01,  1.39545434e+00, -7.66919299e-01],
#        [-1.73426342e+00, -5.39456874e-01, -1.86298687e-01, ...,
#         -3.62167870e-01,  1.37995704e+00, -7.66919299e-01],
#        [-1.73340181e+00, -3.20031232e-01, -1.86298687e-01, ...,
#         -3.62167870e-01,  1.41192021e+00, -7.66919299e-01],
#        ...,
#        [ 1.72682006e+00, -4.29480975e-05, -1.86298687e-01, ...,
#         -3.62167870e-01, -1.31560393e+00,  1.30391816e+00],
#        [ 1.72768167e+00, -1.85606976e-01, -1.86298687e-01, ...,
#         -9.85033311e-02, -1.31608822e+00, -7.66919299e-01],
#        [ 1.72854328e+00, -7.00507951e-01, -1.86298687e-01, ...,
#         -3.62167870e-01, -1.31754109e+00, -7.66919299e-01]])

# %%
from sklearn.cluster import DBSCAN
from sklearn import metrics

# %%
db=DBSCAN(eps=0.9, min_samples=10)
db.fit(dbs)
# Out:
# DBSCAN(eps=0.9, min_samples=10)

# %%
db.labels_
# Out:
# array([0, 0, 0, ..., 1, 0, 0], dtype=int64)

# %%
df_db['cluster']=pd.DataFrame(db.labels_)

# %%
df_db
# Out:
#        ID#  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0        1    28143           0          1          1          1          174
# 1        2    19244           0          1          1          1          215
# 2        3    41354           0          1          1          1         4123
# 3        4    14776           0          1          1          1          500
# 4        5    97752           0          4          1          1        43300
# ...    ...      ...         ...        ...        ...        ...          ...
# 3994  4017    18476           0          1          1          1         8525
# 3995  4018    64385           0          1          1          1          981
# 3996  4019    73597           0          3          1          1        25447
# 3997  4020    54899           0          1          1          1          500
# 3998  4021     3016           0          1          1          1            0
#
# ...

# %%
metrics.silhouette_score(dbs,db.labels_)
metrics.silhouette_score
# Out:
# <function sklearn.metrics.cluster._unsupervised.silhouette_score(X, labels, *, metric='euclidean', sample_size=None, random_state=None, **kwds)>

# %%
metrics.silhouette_score(dbs,db.labels_)
# Out:
# 0.1634053342602568

# %%
df_db.cluster.value_counts()
# Out:
#  0    2209
#  1     926
# -1     864
# Name: cluster, dtype: int64

# %%
df_db.groupby('cluster').agg(['mean'])
# Out:
#                  ID#        Balance  Qual_miles cc1_miles cc2_miles cc3_miles  \
#                 mean           mean        mean      mean      mean      mean
# cluster
# -1       1788.414352  156084.421296  661.672454  2.616898   1.06713  1.056713
#  0       2183.141240   50187.924400    0.963785  1.631507   1.00000  1.000000
#  1       1824.529158   52494.215983    2.699784  2.560475   1.00000  1.000000
#
#           Bonus_miles Bonus_trans Flight_miles_12mo Flight_trans_12  \
#                  mean        mean              mean            mean
# cluster
# -1       34778.962963   19.876157       1732.396991        5.012731
#  0        8525.519692    8.093255         86.412404        0.296514
#  1       21253.070194   12.251620        164.240821        0.547516
#
#         Days_since_enroll    Award?
#                      mean      mean
# cluster
# -1            4569.427083  0.642361
#  0            3795.887279  0.000000
#  1            4467.623110  1.000000
